# %%
p1 = {
    "Turnaround": [755.286, 612.714],
    "Waiting": [551.429, 408.857],
    "Response": [324.571, 129.714],
    "Penalty Ratio": [6.91622, 2.65334],
    "Throughput": [0.00489853, 0.00489853]
}

p2 = {
    "Turnaround": [237.111, 168.667],
    "Waiting": [183.944, 115.5],
    "Response": [97.1111, 52.2222],
    "Penalty Ratio": [8.81763, 4.81375],
    "Throughput": [0.0186722, 0.018595]
}

p3 = {
    "Turnaround": [1026.33, 945.5],
    "Waiting": [852.25, 771.417],
    "Response": [424.583, 435.167],
    "Penalty Ratio": [5.1408, 4.81162],
    "Throughput": [0.00574438, 0.00573888]
}

test = {
    "Turnaround": [52.2, 14.6],
    "Waiting": [40.8, 3.2],
    "Response": [41.6, 2.4],
    "Penalty Ratio": [26.2, 2.028],
    "Throughput": [0.0877193, 0.0877193]
}

# %%
response = {
    "process 1": [324.571, 129.714],
    "process 2": [97.1111, 52.2222],
    "process 3": [435.167, 424.583],
    "test": [41.6, 2.4]
}

turnaround = {
    "process 1": [755.286, 612.714],
    "process 2": [237.111, 168.667],
    "process 3": [1026.33, 945.5],
    "test": [52.2, 14.6]
}

waiting = {
    "process 1": [551.429, 408.857],
    "process 2": [183.944, 115.5],
    "process 3": [852.25, 771.417],
    "test": [40.8, 3.2]
}

penalty_ratio = {
    "process 1": [6.91622, 2.65334],
    "process 2": [8.81763, 4.81375],
    "process 3": [5.1408, 4.81162],
    "test": [26.2, 2.028]
}

throughput = {
    "process 1": [0.00489853, 0.00489853],
    "process 2": [0.0186722, 0.018595],
    "process 3": [0.00574438, 0.00573888],
    "test": [0.0877193, 0.0877193]
}

# %%
import pandas as pd

sjf = [x[0] for x in list(throughput.values())]
srtf = [x[1] for x in list(throughput.values())]

index = list(response.keys())
df = pd.DataFrame({'sjf': sjf,
                   'srtf': srtf
                   }, index=index)

ax = df.plot.bar(rot=0, figsize=(10, 7), title = "System Throughput", xlabel="Process", ylabel="System Throughput")
